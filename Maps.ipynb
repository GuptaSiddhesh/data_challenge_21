# %%
# !pip install datascience

# %%
# !pip install haversine

# %%
from datascience import *
import pandas as pd
import sys

sys.path.append('/content/drive/MyDrive/Data Challenge/')
import functions

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
station_table = Table.read_table("/content/drive/MyDrive/Data Challenge/VEO_Stops.csv")
Marker.map_table(station_table.select('Lat', 'Lon', 'STATION'))

# %%
exit_table = Table.read_table('/content/drive/MyDrive/Data Challenge/2020/1b/exit_count.csv')

# %%
Marker.map_table(exit_table.select('Lat', 'Lon', 'Name of Exit'))
# Out:
# /usr/local/lib/python3.7/dist-packages/datascience/maps.py:368: FutureWarning: simple_marker is deprecated. Use add_children(Marker) instead
#   f(**self._folium_kwargs)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
map_data = exit_table.select('Lat', 'Lon', 'Name of Exit').with_columns(
    'color', 'blue',
    'radius', exit_table.column('Count') * 150
)
Circle.map_table(map_data).show()
# Out:
# /usr/local/lib/python3.7/dist-packages/datascience/maps.py:368: FutureWarning: circle_marker is deprecated. Use add_children(CircleMarker) instead
#   f(**self._folium_kwargs)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
entry_table = Table.read_table('/content/drive/MyDrive/Data Challenge/2020/1c/entrance_count.csv')

# %%
map_data = entry_table.select('Lat', 'Lon', 'Name of Exit').with_columns(
    'color', 'blue',
    'radius', exit_table.column('Count') * 150
)
Circle.map_table(map_data).show()
# Out:
# /usr/local/lib/python3.7/dist-packages/datascience/maps.py:368: FutureWarning: circle_marker is deprecated. Use add_children(CircleMarker) instead
#   f(**self._folium_kwargs)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# **Veo Ride Stops**

# %%
VEO_data =  pd.read_csv("/content/drive/MyDrive/Data Challenge/VEO_Stops.csv")

data =  pd.read_csv("/content/drive/MyDrive/Data Challenge/2020/data_2020.csv")
data = data[data['DISTANCE'] <= 100]
data = data[data['VEHICLE_TYPE'] == "Scooter"]
data = functions.famous_start_stop(data, VEO_data, dist=50)
data.to_csv("data_2020_table.csv")
# !cp data_2020_table.csv "drive/My Drive/Data Challenge"

# %%
### Famous Start Points
station_table = Table.read_table("/content/drive/MyDrive/Data Challenge/data_2020_table.csv")
map_data = station_table.select('Lat', 'Lon', 'STATION').with_columns(
    'color', 'blue',
    'radius', station_table.column('FAMOUS_START') * 150
)
Circle.map_table(map_data).show()
# Out:
# /usr/local/lib/python3.7/dist-packages/datascience/maps.py:368: FutureWarning: circle_marker is deprecated. Use add_children(CircleMarker) instead
#   f(**self._folium_kwargs)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
### Famous End Points
station_table = Table.read_table("/content/drive/MyDrive/Data Challenge/data_2020_table.csv")
map_data = station_table.select('Lat', 'Lon', 'STATION').with_columns(
    'color', 'blue',
    'radius', station_table.column('FAMOUS_END') * 150
)
Circle.map_table(map_data).show()
# Out:
# /usr/local/lib/python3.7/dist-packages/datascience/maps.py:368: FutureWarning: circle_marker is deprecated. Use add_children(CircleMarker) instead
#   f(**self._folium_kwargs)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
